# %% [markdown]
# # Telco Customer Churn — Interactive Exploration
#
# Use this notebook to explore the data interactively alongside the modular project.

# %%
import sys
sys.path.append('..')  # so src/ imports work from notebooks/

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.dpi'] = 100

# %%
from src.data_loader import load_raw_data, inspect_data
df = load_raw_data()
inspect_data(df)
# Out:
# ════════════════════════════════════════════════════════════
#   DATA INSPECTION
# ════════════════════════════════════════════════════════════
# Shape          : 7,043 rows × 21 columns
# Memory usage   : 6984.7 KB
#
# ── Data types ──────────────────────────────────
# customerID              str
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure                int64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges            str
# Churn                   str
#
# ── Missing values ──────────────────────────────
# ...

# %%
import importlib
import src.preprocessing as preprocessing

importlib.reload(preprocessing)
df_clean = preprocessing.preprocess(df)
df_clean.head()
# Out:
# ════════════════════════════════════════════════════════════
#   PREPROCESSING
# ════════════════════════════════════════════════════════════
#   Remaining null values after preprocessing: 0
#   Final shape: 7,043 rows x 20 columns
#   Target balance - Churn=1: 1,869  (26.5%)
#   Saved processed data -> C:\Users\DELL\Downloads\customer-churn-ml\data\processed\telco_processed.csv
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# ...

# %%
from src.eda import run_eda
run_eda(df_clean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 from src.eda import run_eda
# ----> 2 run_eda(df_clean)
#
# NameError: name 'df_clean' is not defined

# %%
from src.feature_engineering import engineer_features
from src.train_models import train_all_models
from src.evaluate import evaluate_all_models

X_train, X_test, y_train, y_test, preprocessor, feature_names = engineer_features(df_clean)
trained = train_all_models(X_train, y_train)
metrics = evaluate_all_models(trained, X_test, y_test)
